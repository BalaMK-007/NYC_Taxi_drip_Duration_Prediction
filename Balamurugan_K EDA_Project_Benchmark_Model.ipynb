# %% [markdown]
# # Building Basic predictive models over the NYC Taxi Trip Dataset

# %% [markdown]
# Targets:
#     Choosing most suitable evaluation metrics.
#     Benchmark model.
#     K-Nearest Neighbours model.
#     Linear model, interpret the variable coefficients of the model.
#     Decision Tree model, interpret the variable importance.
#     Plot Bar plots.

# %%
#Importing Required libraries.

import numpy as np
import pandas as pd
from datetime import timedelta
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading data with pandas and giving vaiable name tt
tt = pd.read_csv('nyc_taxi_trip_duration.csv')
tt.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1  id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2  id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3  id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4  id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.771164                  N            400
# 1         40.694931                  N           1100
# 2         40.774918                  N           1635
# 3         40.780628                  N           1141
# 4         40.740631                  N            848

# %%
#Rows and columns
tt.shape
# Out:
# (729322, 11)

# %% [markdown]
# We have 729322 rows and 11 columns.

# %%
#Columns and values
tt.columns
tt.iloc[1,:]
# Out:
# id                              id0889885
# vendor_id                               1
# pickup_datetime       2016-03-11 23:35:37
# dropoff_datetime      2016-03-11 23:53:57
# passenger_count                         2
# pickup_longitude               -73.988312
# pickup_latitude                 40.731743
# dropoff_longitude              -73.994751
# dropoff_latitude                40.694931
# store_and_fwd_flag                      N
# trip_duration                        1100
# Name: 1, dtype: object

# %%
#Checking missing values. 
np.sum(pd.isnull(tt))

# %% [markdown]
# # The target variable is continous so I'm using RMSE (Root Mean Squared Error) in Evaluation metric.

# %% [markdown]
# # Benchmark Model

# %%
#Creating column trip duration hour with trip duration column values.
tt['trip_duration_hour'] = tt['trip_duration'].apply(lambda x: x/3600)

# %%
#Creating mean column for the duration hour column.
tt["trip_duration_hour_mean"]=tt["trip_duration_hour"].mean()
tt["trip_duration_hour_mean"].head()
# Out:
# 0    0.264508
# 1    0.264508
# 2    0.264508
# 3    0.264508
# 4    0.264508
# Name: trip_duration_hour_mean, dtype: float64

# %%
tt.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1  id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2  id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3  id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4  id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude store_and_fwd_flag  trip_duration  trip_duration_hour  \
# 0         40.771164                  N            400            0.111111
# 1         40.694931                  N           1100            0.305556
# 2         40.774918                  N           1635            0.454167
# 3         40.780628                  N           1141            0.316944
# 4         40.740631                  N            848            0.235556
#
#    trip_duration_hour_mean
# 0                 0.264508
# 1                 0.264508
# 2                 0.264508
# 3                 0.264508
# 4                 0.264508

# %% [markdown]
# Need to analyze the trip duration mean with respect to mean of pickup time of the day, dropoff time of the day, passener count and store fwd flag columns

# %% [markdown]
# #To have a exact pick time of the day and drop off time of the day we need to extract the values given from the columns pickup_datetime and dropoff_datetime.

# %%
#changing the format of the datetime columns
tt['pickup_datetime'] = pd.to_datetime(tt['pickup_datetime'], format = '%Y-%m-%d %H:%M:%S')
tt['dropoff_datetime'] = pd.to_datetime(tt['dropoff_datetime'], format = '%Y-%m-%d %H:%M:%S')

# %%
#Extract every values and store seperately in different columns.

tt['drop_hour'] = tt['dropoff_datetime'].dt.hour
tt['drop_weekday'] = tt['dropoff_datetime'].dt.weekday
tt['drop_day'] = tt['dropoff_datetime'].dt.day
tt['drop_month'] = tt['dropoff_datetime'].dt.month
tt['drop_year'] = tt['dropoff_datetime'].dt.year
tt['drop_date'] = tt['dropoff_datetime'].dt.date


tt['pick_hour'] = tt['pickup_datetime'].dt.hour
tt['pick_weekday'] = tt['pickup_datetime'].dt.weekday
tt['pick_day'] = tt['pickup_datetime'].dt.day
tt['pick_month'] = tt['pickup_datetime'].dt.month
tt['pick_year'] = tt['pickup_datetime'].dt.year
tt['pick_date'] = tt['pickup_datetime'].dt.date

# %%
tt.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id1080784          2 2016-02-29 16:40:21 2016-02-29 16:47:01
# 1  id0889885          1 2016-03-11 23:35:37 2016-03-11 23:53:57
# 2  id0857912          2 2016-02-21 17:59:33 2016-02-21 18:26:48
# 3  id3744273          2 2016-01-05 09:44:31 2016-01-05 10:03:32
# 4  id0232939          1 2016-02-17 06:42:23 2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude store_and_fwd_flag  ...  drop_day  drop_month  drop_year  \
# 0         40.771164                  N  ...        29           2       2016
# 1         40.694931                  N  ...        11           3       2016
# 2         40.774918                  N  ...        21           2       2016
# 3         40.780628                  N  ...         5           1       2016
# 4         40.740631                  N  ...        17           2       2016
#
#     drop_date  pick_hour  pick_weekday  pick_day  pick_month pick_year  \
# 0  2016-02-29         16             0        29           2      2016
# 1  2016-03-11         23             4        11           3      2016
# 2  2016-02-21         17             6        21           2      2016
# 3  2016-01-05          9             1         5           1      2016
# 4  2016-02-17          6             2        17           2      2016
#
#     pick_date
# 0  2016-02-29
# 1  2016-03-11
# 2  2016-02-21
# 3  2016-01-05
# 4  2016-02-17
#
# [5 rows x 25 columns]

# %%
#importing the shuffle library to create train and test datasets.
from sklearn.utils import shuffle
# Shuffling the Dataset
tt = shuffle(tt, random_state = 42)
#creating 4 divisions
div = int(tt.shape[0]/4)
# 3 sets to train and 1 set to test.
train = tt.loc[:3*div+1,:]
test = tt.loc[3*div+1:]

# %%
train.head()
# Out:
#                id  vendor_id     pickup_datetime    dropoff_datetime  \
# 469114  id2380741          2 2016-05-21 10:40:14 2016-05-21 10:51:11
# 694852  id3946961          2 2016-01-08 18:49:27 2016-01-08 18:52:42
# 696324  id0833913          1 2016-05-22 00:54:10 2016-05-22 01:08:10
# 356496  id1336849          1 2016-06-11 10:32:12 2016-06-11 10:38:50
# 645318  id1610858          1 2016-04-03 10:45:51 2016-04-03 10:57:13
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 469114                1        -73.981796        40.762035         -73.972267
# 694852                5        -73.980965        40.747677         -73.982704
# 696324                1        -73.951065        40.782722         -73.867691
# 356496                1        -73.987625        40.762791         -73.973518
# 645318                3        -73.964333        40.792503         -73.988609
#
#         dropoff_latitude store_and_fwd_flag  ...  drop_day  drop_month  \
# 469114         40.781265                  N  ...        21           5
# 694852         40.741161                  N  ...         8           1
# 696324         40.833664                  N  ...        22           5
# 356496         40.762909                  N  ...        11           6
# 645318         40.758369                  N  ...         3           4
#
#         drop_year   drop_date  pick_hour  pick_weekday  pick_day  pick_month  \
# 469114       2016  2016-05-21         10             5        21           5
# 694852       2016  2016-01-08         18             4         8           1
# 696324       2016  2016-05-22          0             6        22           5
# 356496       2016  2016-06-11         10             5        11           6
# 645318       2016  2016-04-03         10             6         3           4
#
#        pick_year   pick_date
# 469114      2016  2016-05-21
# 694852      2016  2016-01-08
# 696324      2016  2016-05-22
# 356496      2016  2016-06-11
# 645318      2016  2016-04-03
#
# [5 rows x 25 columns]

# %%
train.shape
# Out:
# (589451, 25)

# %%
test.head()
# Out:
#                id  vendor_id     pickup_datetime    dropoff_datetime  \
# 546991  id2240736          1 2016-05-25 07:59:16 2016-05-25 08:05:02
# 43126   id1423404          1 2016-01-18 12:17:13 2016-01-18 12:21:13
# 641450  id1317268          2 2016-03-02 18:39:01 2016-03-02 18:50:12
# 611380  id3335546          1 2016-04-06 19:17:20 2016-04-06 19:18:03
# 62690   id2174190          2 2016-06-21 18:35:31 2016-06-21 18:40:56
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 546991                1        -73.991364        40.732590         -74.000526
# 43126                 2        -73.966225        40.768059         -73.967606
# 641450                1        -73.994926        40.766018         -74.004219
# 611380                1        -73.974388        40.793781         -73.976006
# 62690                 3        -73.963440        40.798557         -73.979736
#
#         dropoff_latitude store_and_fwd_flag  ...  drop_day  drop_month  \
# 546991         40.742283                  N  ...        25           5
# 43126          40.763073                  N  ...        18           1
# 641450         40.742523                  N  ...         2           3
# 611380         40.792339                  N  ...         6           4
# 62690          40.777878                  N  ...        21           6
#
#         drop_year   drop_date  pick_hour  pick_weekday  pick_day  pick_month  \
# 546991       2016  2016-05-25          7             2        25           5
# 43126        2016  2016-01-18         12             0        18           1
# 641450       2016  2016-03-02         18             2         2           3
# 611380       2016  2016-04-06         19             2         6           4
# 62690        2016  2016-06-21         18             1        21           6
#
#        pick_year   pick_date
# 546991      2016  2016-05-25
# 43126       2016  2016-01-18
# 641450      2016  2016-03-02
# 611380      2016  2016-04-06
# 62690       2016  2016-06-21
#
# [5 rows x 25 columns]

# %%
test.shape
# Out:
# (139872, 25)

# %%
# RMSE (Root Mean Squared Error)
# Import mean square error as mse from sklearn and square root from math
from sklearn.metrics import mean_squared_error as mse
from math import sqrt

trip_dur_mean_error = sqrt((mse(test['trip_duration_hour'] , test['trip_duration_hour_mean'])))
trip_dur_mean_error
# Out:
# 0.8904067655425832

# %%
#Pickup time of the day.
pick_up = pd.pivot_table(train, values='trip_duration_hour', index = ['pick_hour'], aggfunc=np.mean)
pick_up
# Out:
#            trip_duration_hour
# pick_hour
# 0                    0.272852
# 1                    0.254333
# 2                    0.237052
# 3                    0.246260
# 4                    0.247365
# 5                    0.230513
# 6                    0.201760
# 7                    0.225605
# 8                    0.260481
# 9                    0.258606
# 10                   0.264242
# 11                   0.264151
# 12                   0.272164
# 13                   0.281840
# 14                   0.301248
# 15                   0.310440
# 16                   0.303630
# 17                   0.289271
# 18                   0.272546
# 19                   0.248635
# 20                   0.235792
# 21                   0.246945
# 22                   0.260718
# 23                   0.254643

# %%
# Initialize new column to zero
test['p_up'] = 0

# Assign mean value corresponding to unique entry
for i in train['pick_hour'].unique():
    test['p_up'][test['pick_hour'] == str(i)] = train['trip_duration_hour'][train['pick_hour'] == str(i)].mean()

# %%
#Calculating RMSE
pickup_error = sqrt(mse(test['trip_duration_hour'] , test['p_up'] ))
pickup_error
# Out:
# 0.9290781075032716

# %%
#Dropoff time of the day
drop_off = pd.pivot_table(train, values='trip_duration_hour', index = ['drop_hour'], aggfunc=np.mean)
drop_off
# Out:
#            trip_duration_hour
# drop_hour
# 0                    0.292695
# 1                    0.255730
# 2                    0.231592
# 3                    0.258366
# 4                    0.229382
# 5                    0.229485
# 6                    0.190441
# 7                    0.197141
# 8                    0.248227
# 9                    0.261141
# 10                   0.268173
# 11                   0.277490
# 12                   0.267208
# 13                   0.274047
# 14                   0.291760
# 15                   0.303358
# 16                   0.300354
# 17                   0.288601
# 18                   0.281581
# 19                   0.264023
# 20                   0.241727
# 21                   0.251507
# 22                   0.251577
# 23                   0.254342

# %%
# Initialize new column to zero
test['d_off'] = 0

# Assign mean value to unique entry
for i in train['drop_hour'].unique():
    test['d_off'][test['drop_hour'] == str(i)] = train['trip_duration_hour'][train['drop_hour'] == str(i)].mean()

# %%
#Calculating RMSE
dropoff_error = sqrt(mse(test['trip_duration_hour'] , test['d_off'] ))
dropoff_error
# Out:
# 0.9290781075032716

# %%
#Passenger Count
p_count = pd.pivot_table(train, values='trip_duration_hour', index = ["passenger_count"], aggfunc=np.mean)
p_count
# Out:
#                  trip_duration_hour
# passenger_count
# 0                          0.092981
# 1                          0.255343
# 2                          0.277822
# 3                          0.287332
# 4                          0.285759
# 5                          0.299641
# 6                          0.300193

# %%
# Initialize new column to zero
test['pass_count'] = 0

# Assign the mean value to unique entry
for i in train['passenger_count'].unique(): 
    test['pass_count'][test['passenger_count'] == str(i)] = train['trip_duration_hour'][train['passenger_count'] == str(i)].mean()

# %%
passenger_error = sqrt(mse(test['trip_duration_hour'] , test['pass_count'] ))
passenger_error
# Out:
# 0.9290781075032716

# %%
#Store and Fwd
store_and_fwd = pd.pivot_table(train, values='trip_duration_hour', index = ["store_and_fwd_flag"], aggfunc=np.mean)
store_and_fwd
# Out:
#                     trip_duration_hour
# store_and_fwd_flag
# N                             0.264109
# Y                             0.304058

# %%
# initializing new column to zero
test['store_fwd'] = 0

# Assign the mean value corresponding to unique entry
for i in train['store_and_fwd_flag'].unique():
    test['store_fwd'][test['store_and_fwd_flag'] == str(i)] = train['trip_duration_hour'][train['store_and_fwd_flag'] == str(i)].mean()

# %%
str_fwd_error = sqrt(mse(test['trip_duration_hour'], test['store_fwd'] ))
str_fwd_error
# Out:
# 0.8904020727484228

# %%
#vendor id
v_id = pd.pivot_table(train, values='trip_duration_hour', index = ["vendor_id"], aggfunc=np.mean)
v_id
# Out:
#            trip_duration_hour
# vendor_id
# 1                    0.232826
# 2                    0.291652

# %%
# initializing new column to zero
test['ven_id'] = 0

# Assign the mean value corresponding to unique entry
for i in train['vendor_id'].unique():
    test['ven_id'][test['vendor_id'] == str(i)] = train['trip_duration_hour'][train['vendor_id'] == str(i)].mean()

# %%
v_error = sqrt(mse(test['vendor_id'] , test['trip_duration_hour'] ))
v_error
# Out:
# 1.6191911214509642

# %%
combo = pd.pivot_table(train, values = 'trip_duration_hour', index = ['passenger_count','pick_hour','drop_hour'], aggfunc = np.mean)
combo
# Out:
#                                      trip_duration_hour
# passenger_count pick_hour drop_hour
# 0               0         0                    0.011458
#                 1         1                    0.004028
#                 2         2                    0.311389
#                 3         3                    0.018889
#                 4         4                    0.001667
# ...                                                 ...
# 6               21        22                   0.317244
#                 22        22                   0.212188
#                           23                   0.338074
#                 23        0                    0.341636
#                           23                   0.303280
#
# [546 rows x 1 columns]

# %%
test['Super_mean'] = 0

s2 = 'pick_hour'
s1 = 'drop_hour'


for i in test[s1].unique():
  
  for j in test[s2].unique():
    test['Super_mean'][(test[s1] == i) & (test[s2]==str(j))] = train['trip_duration'][(train[s1] == i) & (train[s2]==str(j))].mean()

# %%
super_mean_error = sqrt(mse(test['trip_duration'] , test['Super_mean'] ))
super_mean_error
# Out:
# 3344.6811870117776

# %% [markdown]
# The RMSE error of Pick hour is 0.9290781075032716

# %% [markdown]
# The RMSE error of drop hour is 0.9290781075032716

# %% [markdown]
# The RMSE error of Passenger is 0.9290781075032716

# %% [markdown]
# The RMSE error of Store and Fwd flag is 0.8904020727484228

# %% [markdown]
# The RMSE error of vendor_id is 1.6191911214509642

# %% [markdown]
# The RMSE of vendor_id is little high camparing to other errors.

# %% [markdown]
# The pickup, dropoff and passenger errors are equal to each other.

# %% [markdown]
# The store and FWd flag error is little bit less then other errors.
